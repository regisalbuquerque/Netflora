# %% [markdown]
# <a href="https://colab.research.google.com/github/regisalbuquerque/Netflora/blob/main/Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar libraries
import pandas as pd

# %%
features_names = ['Outlook', 'Temperature', 'Humidity', 'Wind']
target_name = ['Play Tennis']
labels = ['Yes', 'No']
col_names = features_names + target_name
df = pd.read_csv('https://gist.githubusercontent.com/DiogoRibeiro7/c6590d0cf119e87c39e31c21a9c0f3a8/raw/4a8e3da267a0c1f0d650901d8295a5153bde8b21/PlayTennis.csv', header=0, names=col_names ,delimiter=',')


# Imprimir parte do DataSet para entendimento
print("Quantidade de Linhas: ", len(df.index))
df.head(14)
# Out:
# Quantidade de Linhas:  14
#      Outlook Temperature Humidity    Wind Play Tennis
# 0      Sunny         Hot     High    Weak          No
# 1      Sunny         Hot     High  Strong          No
# 2   Overcast         Hot     High    Weak         Yes
# 3       Rain        Mild     High    Weak         Yes
# 4       Rain        Cool   Normal    Weak         Yes
# 5       Rain        Cool   Normal  Strong          No
# 6   Overcast        Cool   Normal  Strong         Yes
# 7      Sunny        Mild     High    Weak          No
# 8      Sunny        Cool   Normal    Weak         Yes
# 9       Rain        Mild   Normal    Weak         Yes
# 10     Sunny        Mild   Normal  Strong         Yes
# 11  Overcast        Mild     High  Strong         Yes
# 12  Overcast         Hot   Normal    Weak         Yes
# 13      Rain        Mild     High  Strong          No
